# %% [markdown]
# ## Open Government Data, provided by **Landeshauptstadt München**
# *Autogenerated Python starter code for data set with identifier* **173@lhm**

# %% [markdown]
# ## Dataset
# # **Bundestagswahlen 2017 - Ergebnisse München**

# %% [markdown]
# ## Description
#
# {{ DATASET_DESCRIPTION }}

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://opendata.muenchen.de/dataset/bundestagswahlen-2017-ergebnisse-munchen)

# %% [markdown]
# ## Metadata
# - **Issued** `2018-03-03T08:05:49`
# - **Modified** `2021-10-27T15:10:32`
# - **Startdate** `None`
# - **Enddate** `None`
# - **Theme** `['http://publications.europa.eu/resource/authority/data-theme/TECH']`
# - **Keyword** `['Bundestagswahl', 'Wahlen']`
# - **Publisher** `['statistisches-amt']`
# - **Landingpage** `https://opendata.muenchen.de/dataset/bundestagswahlen-2017-ergebnisse-munchen`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`6` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1731
# Title                    : Bundestagswahl 2017 Erststimmen nach Wahlbezirken
# Issued                   : 2018-03-03T09:06:29
# Modified                 : 2018-03-03T08:06:29
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/d95b5aa1-83d0-4c15-9a12-661c2e3622ff/resource/14732d87-21b4-4689-b824-68b2d5a43248/download/btw2017amtlicherststimmenwahlbezirke.csv')

# Distribution 1
# Ktzhdistid               : 1732
# Title                    : Bundestagswahl 2017 Erststimmen nach Wahlkreisen
# Issued                   : 2018-03-03T09:06:49
# Modified                 : 2018-03-03T08:06:49
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/d95b5aa1-83d0-4c15-9a12-661c2e3622ff/resource/339d69ec-69ce-4675-a397-3fb54507c124/download/btw2017amtlicherststimmenwahlkreise.csv')

# Distribution 2
# Ktzhdistid               : 1733
# Title                    :  Bundestagswahl 2017 Erststimmen nach Stadtbezirken
# Issued                   : 2018-03-03T09:07:05
# Modified                 : 2018-03-03T08:07:05
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/d95b5aa1-83d0-4c15-9a12-661c2e3622ff/resource/bcf97087-9198-4736-8715-23975e1229c5/download/btw2017amtlicherststimmenstadtbezirke.csv')

# Distribution 3
# Ktzhdistid               : 1734
# Title                    : Bundestagswahl 2017 Zweitstimmen nach Wahlkreisen
# Issued                   : 2018-03-03T09:07:21
# Modified                 : 2018-03-03T08:07:21
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/d95b5aa1-83d0-4c15-9a12-661c2e3622ff/resource/1655cdc8-13c3-489b-94a6-19a887da714d/download/btw2017amtlichzweitstimmenwahlkreise.csv')

# Distribution 4
# Ktzhdistid               : 1735
# Title                    : Bundestagswahl 2017 Zweitstimmen nach Wahlbezirken
# Issued                   : 2018-03-03T09:07:34
# Modified                 : 2018-03-03T08:07:34
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/d95b5aa1-83d0-4c15-9a12-661c2e3622ff/resource/fba0bca0-aaa6-4888-a5d9-ecf25c845575/download/btw2017amtlichzweitstimmenwahlbezirke.csv')

# Distribution 5
# Ktzhdistid               : 1736
# Title                    : Bundestagswahl 2017 Zweitstimmen nach Stadtbezirken
# Issued                   : 2018-03-03T09:08:12
# Modified                 : 2018-03-03T08:08:11
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/d95b5aa1-83d0-4c15-9a12-661c2e3622ff/resource/7b1ee971-6c60-4c9b-9675-8aa211a51be7/download/btw2017amtlichzweitstimmenstadtbezirke.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Questions about the data?** Statistisches Amt | Data Shop |
