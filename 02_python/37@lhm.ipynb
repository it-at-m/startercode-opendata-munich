# %% [markdown]
# ## Open Government Data, provided by **Landeshauptstadt München**
# *Autogenerated Python starter code for data set with identifier* **37@lhm**

# %% [markdown]
# ## Dataset
# # **Daten der Raddauerzählstellen München 2023**

# %% [markdown]
# ## Description
#
# {{ DATASET_DESCRIPTION }}

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://opendata.muenchen.de/dataset/daten-der-raddauerzaehlstellen-muenchen-2023)

# %% [markdown]
# ## Metadata
# - **Issued** `2023-02-06T11:36:10`
# - **Modified** `2023-09-07T12:18:47`
# - **Startdate** `None`
# - **Enddate** `None`
# - **Theme** `['http://publications.europa.eu/resource/authority/data-theme/TECH']`
# - **Keyword** `['Fahrrad', 'Raddauerzählstellen', 'Raddauerzählstellen 2023']`
# - **Publisher** `['mobilitaetsreferat']`
# - **Landingpage** `https://opendata.muenchen.de/dataset/daten-der-raddauerzaehlstellen-muenchen-2023`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`16` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 371
# Title                    : 15 Minuten-Werte - Januar 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-02-06T11:50:08
# Modified                 : 2023-02-06T11:50:08
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/63899327-2f90-42f8-8953-9344a158129b/download/rad_2023_01_15min.csv')

# Distribution 1
# Ktzhdistid               : 372
# Title                    : Tageswerte und Wetter - Januar 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-02-06T11:50:52
# Modified                 : 2023-02-06T11:50:52
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/c2d22114-8ca0-44d5-895a-39b422977cff/download/rad_2023_01_tage.csv')

# Distribution 2
# Ktzhdistid               : 373
# Title                    : 15 Minuten-Werte - Februar 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-03-13T10:45:38
# Modified                 : 2023-03-13T10:45:38
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/6f9f934a-d70c-4deb-b365-de79c21f5e44/download/rad_2023_02_15min.csv')

# Distribution 3
# Ktzhdistid               : 374
# Title                    : Tageswerte und Wetter - Februar 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-03-13T10:46:45
# Modified                 : 2023-03-13T10:46:45
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/5506ca79-edb7-4241-90eb-e8406430fab4/download/rad_2023_02_tage.csv')

# Distribution 4
# Ktzhdistid               : 375
# Title                    : 15 Minuten-Werte - März 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-04-11T08:06:02
# Modified                 : 2023-04-11T08:06:02
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/e8536f7f-d03a-4dce-8b9e-81907fdff40f/download/rad_2023_03_15min.csv')

# Distribution 5
# Ktzhdistid               : 376
# Title                    : Tageswerte und Wetter - März 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-04-11T08:06:48
# Modified                 : 2023-04-11T08:06:48
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/51898d07-2aa5-4ee7-977d-c0b80f8910a3/download/rad_2023_03_tage.csv')

# Distribution 6
# Ktzhdistid               : 377
# Title                    : 15 Minuten-Werte - April 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-05-05T06:29:31
# Modified                 : 2023-05-05T06:29:31
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/653f1acb-f02e-4ba6-8dc3-fe1c975a28be/download/rad_2023_04_15min.csv')

# Distribution 7
# Ktzhdistid               : 378
# Title                    : Tageswerte und Wetter - April 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-05-05T06:30:28
# Modified                 : 2023-05-05T06:30:28
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/b12f851c-70a4-4864-9efe-1f6ee85c24dc/download/rad_2023_04_tage.csv')

# Distribution 8
# Ktzhdistid               : 379
# Title                    : 15 Minuten-Werte - Mai 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-06-07T07:52:39
# Modified                 : 2023-06-07T07:52:39
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/c5e32d17-6162-4d66-b3a1-e5509eba07e2/download/rad_2023_05_15min.csv')

# Distribution 9
# Ktzhdistid               : 380
# Title                    : Tageswerte und Wetter - Mai 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-06-07T07:53:42
# Modified                 : 2023-06-07T07:53:42
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/98d6814b-8850-4859-9266-f04fd941e68a/download/rad_2023_05_tage.csv')

# Distribution 10
# Ktzhdistid               : 381
# Title                    : 15 Minuten-Werte - Juni 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-07-17T08:54:06
# Modified                 : 2023-07-17T08:54:06
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/f79567a5-9d2a-4274-b54a-5d34112ac13c/download/rad_2023_06_15min.csv')

# Distribution 11
# Ktzhdistid               : 382
# Title                    : Tageswerte und Wetter - Juni 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-07-17T08:55:37
# Modified                 : 2023-07-17T08:55:37
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/9bfaf5ce-868b-44bb-8963-45028087dfc7/download/rad_2023_06_tage.csv')

# Distribution 12
# Ktzhdistid               : 383
# Title                    : 15 Minuten-Werte - Juli 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-08-03T16:11:06
# Modified                 : 2023-08-03T16:11:06
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/24f8cb55-05b5-40d0-9ef7-fc66d1e53fd1/download/rad_2023_07_15min.csv')

# Distribution 13
# Ktzhdistid               : 384
# Title                    : Tageswerte und Wetter - Juli 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-08-03T16:12:12
# Modified                 : 2023-08-03T16:12:12
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/26fb8325-c885-4911-8a10-c4b880402283/download/rad_2023_07_tage.csv')

# Distribution 14
# Ktzhdistid               : 385
# Title                    : 15 Minuten-Werte - August 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-09-07T12:17:46
# Modified                 : 2023-09-07T12:17:46
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/88ca9f2b-3505-4855-9b7d-dee58bc5eb72/download/rad_2023_08_15min.csv')

# Distribution 15
# Ktzhdistid               : 386
# Title                    : Tageswerte und Wetter - August 2023 - Daten der Raddauerzählstellen München
# Issued                   : 2023-09-07T12:18:47
# Modified                 : 2023-09-07T12:18:47
# Rights                   : dl-by-de/2.0

df = get_dataset('https://opendata.muenchen.de/dataset/780d7f77-e5de-47bb-8b34-9bc321c567a1/resource/d87fab0d-5701-4507-8575-f76408805967/download/rad_2023_08_tage.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Questions about the data?** Mobilitätsreferat - Verkehrs- und Verhaltensdaten | Data Shop |
